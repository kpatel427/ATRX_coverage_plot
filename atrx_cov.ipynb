# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
#%matplotlib qt

lst_samples = []
lst_transcripts = []

df = pd.read_table('/Users/patelk26/Desktop/ATRX_coverage/ATRX_exon_coverage_nblsamples.txt', delim_whitespace=True)
#print(df)


#Adding a column with the result of cov/fpkm
df['cov/fpkm'] = df.apply(lambda row: row.read_count / row.FPKM, axis=1)
df

#writing df to csv
df.to_csv('/Users/patelk26/Desktop/ATRX_coverage/ATRX_exon_coverage_NBLsamples.csv', sep=',')

#df.Sample.unique()

# %%
#sns.swarmplot(x='exon_n', y='cov/fpkm', data=df, hue = "Sample")
